# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import OneHotEncoder, StandardSca1er
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import joblib
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 from sklearn.preprocessing import OneHotEncoder, StandardSca1er
#       5 from sklearn.model_selection import GridSearchCV
#       6 from lightgbm import LGBMRegressor
#
# ImportError: cannot import name 'StandardSca1er' from 'sklearn.preprocessing' (C:\Python311\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
df = pd.read_csv("student_exam_data.csv")

# %%
df
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0       4.370861            81.889703          0
# 1       9.556429            72.165782          1
# 2       7.587945            58.571657          0
# 3       6.387926            88.827701          1
# 4       2.404168            81.083870          0
# ..           ...                  ...        ...
# 495     4.180170            45.494924          0
# 496     6.252905            95.038815          1
# 497     1.699612            48.209118          0
# 498     9.769553            97.014241          1
# 499     9.875897            66.760346          1
#
# [500 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# Study Hours            0
# Previous Exam Score    0
# Pass/Fail              0
# dtype: int64

# %%
sns.countplot(df["Previous Exam Score"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df["Study Hours"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df["Pass/Fail"])
# Out:
# <Axes: ylabel='count'>

# %%
df.describe()
# Out:
#        Study Hours  Previous Exam Score   Pass/Fail
# count   500.000000           500.000000  500.000000
# mean      5.487055            68.917084    0.368000
# std       2.688196            17.129607    0.482744
# min       1.045554            40.277921    0.000000
# 25%       3.171517            53.745955    0.000000
# 50%       5.618474            68.309294    0.000000
# 75%       7.805124            83.580209    1.000000
# max       9.936683            99.983060    1.000000
