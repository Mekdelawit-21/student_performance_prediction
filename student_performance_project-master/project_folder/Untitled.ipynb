# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the saved model and scaler
with open('model_pkl', 'rb') as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Load the saved model and scaler
#       2 with open('model_pkl', 'rb') as f:
# ----> 3     model = pickle.load(f)
#
# NameError: name 'pickle' is not defined

# %%
with open('scaler_pkl', 'rb') as f:
    scaler = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 with open('scaler_pkl', 'rb') as f:
# ----> 2     scaler = pickle.load(f)
#
# NameError: name 'pickle' is not defined

# %%
# Define the input space
study_hours_range = np.linspace(X['Study Hours'].min(), X['Study Hours'].max(), 100)
prev_exam_score_range = np.linspace(X['Previous Exam Score'].min(), X['Previous Exam Score'].max(), 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Define the input space
# ----> 2 study_hours_range = np.linspace(X['Study Hours'].min(), X['Study Hours'].max(), 100)
#       3 prev_exam_score_range = np.linspace(X['Previous Exam Score'].min(), X['Previous Exam Score'].max(), 100)
#
# NameError: name 'X' is not defined

# %%
# Create a grid of input values
study_hours_grid, prev_exam_score_grid = np.meshgrid(study_hours_range, prev_exam_score_range)
input_space = np.c_[study_hours_grid.ravel(), prev_exam_score_grid.ravel()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Create a grid of input values
# ----> 2 study_hours_grid, prev_exam_score_grid = np.meshgrid(study_hours_range, prev_exam_score_range)
#       3 input_space = np.c_[study_hours_grid.ravel(), prev_exam_score_grid.ravel()]
#
# NameError: name 'study_hours_range' is not defined

# %%
# Scale the input features
scaled_input_space = scaler.transform(input_space)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Scale the input features
# ----> 2 scaled_input_space = scaler.transform(input_space)
#
# NameError: name 'scaler' is not defined

# %%
# Make predictions on the scaled input space
predictions = model.predict(scaled_input_space)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Make predictions on the scaled input space
# ----> 2 predictions = model.predict(scaled_input_space)
#
# NameError: name 'model' is not defined

# %%
# Reshape predictions to the shape of the input space
predictions_grid = predictions.reshape(study_hours_grid.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Reshape predictions to the shape of the input space
# ----> 2 predictions_grid = predictions.reshape(study_hours_grid.shape)
#
# NameError: name 'predictions' is not defined

# %%
# Create a contour plot
plt.contourf(study_hours_grid, prev_exam_score_grid, predictions_grid, cmap=plt.cm.Paired, alpha=0.8)
plt.scatter(X['Study Hours'], X['Previous Exam Score'], c=y, edgecolors='k', cmap=plt.cm.Paired, marker='o', s=50)
plt.xlabel('Study Hours')
plt.ylabel('Previous Exam Score')
plt.title('Logistic Regression Decision Boundary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Create a contour plot
# ----> 2 plt.contourf(study_hours_grid, prev_exam_score_grid, predictions_grid, cmap=plt.cm.Paired, alpha=0.8)
#       3 plt.scatter(X['Study Hours'], X['Previous Exam Score'], c=y, edgecolors='k', cmap=plt.cm.Paired, marker='o', s=50)
#       4 plt.xlabel('Study Hours')
#
# NameError: name 'study_hours_grid' is not defined
